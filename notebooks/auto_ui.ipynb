# %%
import sys
sys.path.append("../")

# %%
from dotenv import load_dotenv
from src.pytaifex.official_ttb import OfficialTTB
import os

load_dotenv()

# %%
TTB_PATH = str(os.getenv("TTB_PATH"))
ACCOUNT = str(os.getenv("ACCOUNT"))
PASSWORD = str(os.getenv("PASSWORD"))

# %%
client = OfficialTTB(TTB_PATH, force=True)

# %%
client.login(ACCOUNT, PASSWORD)
